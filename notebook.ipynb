# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions. This data does contain null values and some outliers, but handling these is out of scope for the project. Feel free to experiment after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!
netflix_df = pd.read_csv('netflix_data.csv')
for i in netflix_df.iterrows():
    print(i)
# Out:
# (0, show_id                                                        s1
# type                                                      TV Show
# title                                                          3%
# director                                                      NaN
# cast            João Miguel, Bianca Comparato, Michel Gomes, R...
# country                                                    Brazil
# date_added                                        August 14, 2020
# release_year                                                 2020
# duration                                                        4
# description     In a future where the elite inhabit an island ...
# genre                                            International TV
# Name: 0, dtype: object)
# (1, show_id                                                        s2
# type                                                        Movie
# title                                                        7:19
# director                                        Jorge Michel Grau
# cast            Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# country                                                    Mexico
# date_added                                      December 23, 2016
# release_year                                                 2016
# duration                                                       93
# description     After a devastating earthquake hits Mexico Cit...
# genre                                                      Dramas
# Name: 1, dtype: object)
# (2, show_id                                                        s3
# type                                                        Movie
# title                                                       23:59
# director                                             Gilbert Chan
# cast            Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# country                                                 Singapore
# date_added                                      December 20, 2018
# release_year                                                 2011
# duration                                                       78
# description     When an army recruit is found dead, his fellow...
# genre                                               Horror Movies
# Name: 2, dtype: object)
# (3, show_id                                                        s4
# type                                                        Movie
# title                                                           9
# director                                              Shane Acker
# cast            Elijah Wood, John C. Reilly, Jennifer Connelly...
# country                                             United States
# date_added                                      November 16, 2017
# release_year                                                 2009
# duration                                                       80
# description     In a postapocalyptic world, rag-doll robots hi...
# genre                                                      Action
# Name: 3, dtype: object)
# (4, show_id                                                        s5
# type                                                        Movie
# title                                                          21
# director                                           Robert Luketic
# cast            Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# country                                             United States
# date_added                                        January 1, 2020
# release_year                                                 2008
# duration                                                      123
# description     A brilliant group of students become card-coun...
# genre                                                      Dramas
# Name: 4, dtype: object)
# (5, show_id                                                        s6
# type                                                      TV Show
# title                                                          46
# director                                              Serdar Akar
# cast            Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# country                                                    Turkey
# date_added                                           July 1, 2017
# release_year                                                 2016
# duration                                                        1
# description     A genetics professor experiments with a treatm...
# genre                                            International TV
# Name: 5, dtype: object)
# (6, show_id                                                        s7
# type                                                        Movie
# title                                                         122
# director                                          Yasir Al Yasiri
# cast            Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# country                                                     Egypt
# date_added                                           June 1, 2020
# release_year                                                 2019
# duration                                                       95
# description     After an awful accident, a couple admitted to ...
# genre                                               Horror Movies
# Name: 6, dtype: object)
# (7, show_id                                                        s8
# type                                                        Movie
# title                                                         187
# director                                           Kevin Reynolds
# cast            Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# country                                             United States
# date_added                                       November 1, 2019
# release_year                                                 1997
# duration                                                      119
# description     After one of his high school students attacks ...
# genre                                                      Dramas
# Name: 7, dtype: object)
# (8, show_id                                                        s9
# type                                                        Movie
# title                                                         706
# director                                            Shravan Kumar
# cast            Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...
# country                                                     India
# date_added                                          April 1, 2019
# release_year                                                 2019
# duration                                                      118
# description     When a doctor goes missing, his psychiatrist w...
# genre                                               Horror Movies
# Name: 8, dtype: object)
# (9, show_id                                                       s10
# type                                                        Movie
# title                                                        1920
# director                                             Vikram Bhatt
# cast            Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# country                                                     India
# date_added                                      December 15, 2017
# release_year                                                 2008
# duration                                                      143
# description     An architect and his wife move into a castle t...
# genre                                               Horror Movies
# Name: 9, dtype: object)
# (10, show_id                                                       s11
# type                                                        Movie
# title                                                        1922
# director                                             Zak Hilditch
# cast            Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# country                                             United States
# date_added                                       October 20, 2017
# release_year                                                 2017
# duration                                                      103
# description     A farmer pens a confession admitting to his wi...
# genre                                                      Dramas
# Name: 10, dtype: object)
# (11, show_id                                                       s12
# type                                                      TV Show
# title                                                        1983
# director                                                      NaN
# cast            Robert Więckiewicz, Maciej Musiał, Michalina O...
# country                                                    Poland
# date_added                                      November 30, 2018
# release_year                                                 2018
# duration                                                        1
# description     In this dark alt-history thriller, a naïve law...
# genre                                                    Crime TV
# Name: 11, dtype: object)
# (12, show_id                                                       s13
# type                                                      TV Show
# title                                                        1994
# director                                     Diego Enrique Osorno
# cast                                                          NaN
# country                                                    Mexico
# date_added                                           May 17, 2019
# release_year                                                 2019
# duration                                                        1
# description     Archival video and new interviews examine Mexi...
# genre                                                    Crime TV
# Name: 12, dtype: object)
# (13, show_id                                                       s14
# type                                                        Movie
# title                                                       2,215
# director                                      Nottapon Boonprakob
# cast                                           Artiwara Kongmalai
# country                                                  Thailand
# date_added                                          March 1, 2019
# release_year                                                 2018
# duration                                                       89
# description     This intimate documentary follows rock star Ar...
# genre                                               Documentaries
# Name: 13, dtype: object)
# (14, show_id                                                       s15
# type                                                        Movie
# title                                                        3022
# director                                               John Suits
# cast            Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
# country                                             United States
# date_added                                         March 19, 2020
# release_year                                                 2019
# duration                                                       91
# description     Stranded when the Earth is suddenly destroyed ...
# genre                                          Independent Movies
# Name: 14, dtype: object)
# (15, show_id                                                       s16
# type                                                        Movie
# title                                                      Oct-01
# director                                           Kunle Afolayan
# cast            Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# country                                                   Nigeria
# date_added                                      September 1, 2019
# release_year                                                 2014
# duration                                                      149
# description     Against the backdrop of Nigeria's looming inde...
# genre                                                      Dramas
# Name: 15, dtype: object)
# (16, show_id                                                       s17
# type                                                      TV Show
# title                                                      Feb-09
# director                                                      NaN
# cast            Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
# country                                                       NaN
# date_added                                         March 20, 2019
# release_year                                                 2018
# duration                                                        1
# description     As a psychology professor faces Alzheimer's, h...
# genre                                            International TV
# Name: 16, dtype: object)
# (17, show_id                                                       s18
# type                                                        Movie
# title                                                      22-Jul
# director                                          Paul Greengrass
# cast            Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# country                                                    Norway
# date_added                                       October 10, 2018
# release_year                                                 2018
# duration                                                      144
# description     After devastating terror attacks in Norway, a ...
# genre                                                      Dramas
# Name: 17, dtype: object)
# (18, show_id                                                       s19
# type                                                        Movie
# title                                                      15-Aug
# director                                       Swapnaneel Jayakar
# cast            Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...
# country                                                     India
# date_added                                         March 29, 2019
# release_year                                                 2019
# duration                                                      124
# description     On India's Independence Day, a zany mishap in ...
# genre                                                    Comedies
# Name: 18, dtype: object)
# (19, show_id                                                       s20
# type                                                        Movie
# title                                                         '89
# director                                                      NaN
# cast                           Lee Dixon, Ian Wright, Paul Merson
# country                                            United Kingdom
# date_added                                           May 16, 2018
# release_year                                                 2017
# duration                                                       87
# description     Mixing old footage with interviews, this is th...
# genre                                               Sports Movies
# Name: 19, dtype: object)
# (20, show_id                                                       s21
# type                                                        Movie
# title                                        ​​Kuch Bheege Alfaaz
# director                                                     Onir
# cast            Geetanjali Thapa, Zain Khan Durrani, Shray Rai...
# country                                                     India
# date_added                                      September 1, 2018
# release_year                                                 2018
# duration                                                      110
# description     After accidentally connecting over the Interne...
# genre                                                      Dramas
# Name: 20, dtype: object)
# (21, show_id                                                       s22
# type                                                        Movie
# title                                                ​Goli Soda 2
# director                                             Vijay Milton
# cast            Samuthirakani, Bharath Seeni, Vinoth, Esakki B...
# country                                                     India
# date_added                                     September 15, 2018
# release_year                                                 2018
# duration                                                      128
# description     A taxi driver, a gangster and an athlete strug...
# genre                                                      Action
# Name: 21, dtype: object)
# (22, show_id                                                       s23
# type                                                        Movie
# title                                          ​Maj Rati ​​Keteki
# director                                        Santwana Bardoloi
# cast            Adil Hussain, Shakil Imtiaz, Mahendra Rabha, S...
# country                                                     India
# date_added                                     September 15, 2018
# release_year                                                 2017
# duration                                                      117
# description     A successful writer returns to the town that l...
# genre                                                      Dramas
# Name: 22, dtype: object)
# (23, show_id                                                       s24
# type                                                        Movie
# title                                                 ​Mayurakshi
# director                                              Atanu Ghosh
# cast            Soumitra Chatterjee, Prasenjit Chatterjee, Ind...
# country                                                     India
# date_added                                     September 15, 2018
# release_year                                                 2017
# duration                                                      100
# description     When a middle-aged divorcee returns to Kolkata...
# genre                                                      Dramas
# Name: 23, dtype: object)
# (24, show_id                                                       s25
# type                                                      TV Show
# title                         ​SAINT SEIYA: Knights of the Zodiac
# director                                                      NaN
# cast            Bryson Baugus, Emily Neves, Blake Shepard, Pat...
# country                                                     Japan
# date_added                                       January 23, 2020
# release_year                                                 2020
# duration                                                        2
# description     Seiya and the Knights of the Zodiac rise again...
# genre                                                Anime Series
# Name: 24, dtype: object)
# (25, show_id                                                       s26
# type                                                        Movie
# title                                                    (T)ERROR
# director                   Lyric R. Cabral, David Felix Sutcliffe
# cast                                                          NaN
# country                                             United States
# date_added                                          June 30, 2016
# release_year                                                 2015
# duration                                                       84
# description     This real-life look at FBI counterterrorism op...
# genre                                               Documentaries
# Name: 25, dtype: object)
# (26, show_id                                                       s27
# type                                                      TV Show
# title                                                    (Un)Well
# director                                                      NaN
# cast                                                          NaN
# country                                             United States
# date_added                                        August 12, 2020
# release_year                                                 2020
# duration                                                        1
# description     This docuseries takes a deep dive into the luc...
# genre                                                  Reality TV
# Name: 26, dtype: object)
# (27, show_id                                                       s28
# type                                                        Movie
# title                                                      #Alive
# director                                                   Cho Il
# cast                                     Yoo Ah-in, Park Shin-hye
# country                                               South Korea
# date_added                                      September 8, 2020
# release_year                                                 2020
# duration                                                       99
# description     As a grisly virus rampages a city, a lone man ...
# genre                                               Horror Movies
# Name: 27, dtype: object)
# (28, show_id                                                       s29
# type                                                        Movie
# title                               #AnneFrank - Parallel Stories
# director                              Sabina Fedeli, Anna Migotto
# cast                                  Helen Mirren, Gengher Gatti
# country                                                     Italy
# date_added                                           July 1, 2020
# release_year                                                 2019
# duration                                                       95
# description     Through her diary, Anne Frank's story is retol...
# genre                                               Documentaries
# Name: 28, dtype: object)
# (29, show_id                                                       s30
# type                                                      TV Show
# title                                                    #blackAF
# director                                                      NaN
# cast            Kenya Barris, Rashida Jones, Iman Benson, Genn...
# country                                             United States
# date_added                                         April 17, 2020
# release_year                                                 2020
# duration                                                        1
# description     Kenya Barris and his family navigate relations...
# genre                                                 TV Comedies
# Name: 29, dtype: object)
# (30, show_id                                                       s31
# type                                                        Movie
# title                                            #cats_the_mewvie
# director                                         Michael Margolis
# cast                                                          NaN
# country                                                    Canada
# date_added                                       February 5, 2020
# release_year                                                 2020
# duration                                                       90
# description     This pawesome documentary explores how our fel...
# genre                                               Documentaries
# Name: 30, dtype: object)
# (31, show_id                                                       s32
# type                                                        Movie
# title                                           #FriendButMarried
# director                                            Rako Prijanto
# cast            Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...
# country                                                 Indonesia
# date_added                                           May 21, 2020
# release_year                                                 2018
# duration                                                      102
# description     Pining for his high school crush for years, a ...
# genre                                                      Dramas
# Name: 31, dtype: object)
# (32, show_id                                                       s33
# type                                                        Movie
# title                                         #FriendButMarried 2
# director                                            Rako Prijanto
# cast            Adipati Dolken, Mawar de Jongh, Sari Nila, Von...
# country                                                 Indonesia
# date_added                                          June 28, 2020
# release_year                                                 2020
# duration                                                      104
# description     As Ayu and Ditto finally transition from best ...
# genre                                                      Dramas
# Name: 32, dtype: object)
# (33, show_id                                                       s34
# type                                                        Movie
# title                                                #realityhigh
# director                                         Fernando Lebrija
# cast            Nesta Cooper, Kate Walsh, John Michael Higgins...
# country                                             United States
# date_added                                      September 8, 2017
# release_year                                                 2017
# duration                                                       99
# description     When nerdy high schooler Dani finally attracts...
# genre                                                    Comedies
# Name: 33, dtype: object)
# (34, show_id                                                       s35
# type                                                        Movie
# title                                                       #Roxy
# director                                          Michael Kennedy
# cast            Jake Short, Sarah Fisher, Booboo Stewart, Dann...
# country                                                    Canada
# date_added                                         April 10, 2019
# release_year                                                 2018
# duration                                                      105
# description     A teenage hacker with a huge nose helps a cool...
# genre                                                    Comedies
# Name: 34, dtype: object)
# (35, show_id                                                       s36
# type                                                        Movie
# title                                                   #Rucker50
# director                                    Robert McCullough Jr.
# cast                                                          NaN
# country                                             United States
# date_added                                       December 1, 2016
# release_year                                                 2016
# duration                                                       56
# description     This documentary celebrates the 50th anniversa...
# genre                                               Documentaries
# Name: 35, dtype: object)
# (36, show_id                                                       s37
# type                                                        Movie
# title                                                     #Selfie
# director                                           Cristina Jacob
# cast            Flavia Hojda, Crina Semciuc, Olimpia Melinte, ...
# country                                                   Romania
# date_added                                           June 1, 2019
# release_year                                                 2014
# duration                                                      125
# description     Two days before their final exams, three teen ...
# genre                                                    Comedies
# Name: 36, dtype: object)
# (37, show_id                                                       s38
# type                                                        Movie
# title                                                  #Selfie 69
# director                                           Cristina Jacob
# cast            Maia Morgenstern, Olimpia Melinte, Crina Semci...
# country                                                   Romania
# date_added                                           June 1, 2019
# release_year                                                 2016
# duration                                                      119
# description     After a painful breakup, a trio of party-lovin...
# genre                                                    Comedies
# Name: 37, dtype: object)
# (38, show_id                                                       s39
# type                                                      TV Show
# title                                         แผนร้ายนายเจ้าเล่ห์
# director                                                      NaN
# cast            Chutavuth Pattarakampol, Sheranut Yusananda, N...
# country                                                       NaN
# date_added                                         March 30, 2019
# release_year                                                 2016
# duration                                                        1
# description     When two brothers fall for two sisters, they q...
# genre                                            International TV
# Name: 38, dtype: object)
# (39, show_id                                                       s40
# type                                                        Movie
# title                                              ¡Ay, mi madre!
# director                                              Frank Ariza
# cast            Estefanía de los Santos, Secun de la Rosa, Ter...
# country                                                     Spain
# date_added                                          July 19, 2019
# release_year                                                 2019
# duration                                                       81
# description     When her estranged mother suddenly dies, a wom...
# genre                                                    Comedies
# Name: 39, dtype: object)
# (40, show_id                                                       s41
# type                                                        Movie
# title                                                 Çarsi Pazar
# director                                          Muharrem Gülmez
# cast            Erdem Yener, Ayhan Taş, Emin Olcay, Muharrem G...
# country                                                    Turkey
# date_added                                         March 10, 2017
# release_year                                                 2015
# duration                                                       97
# description     The slacker owner of a public bath house ralli...
# genre                                                    Comedies
# Name: 40, dtype: object)
# (41, show_id                                                       s42
# type                                                        Movie
# title                                                  Ég man þig
# director                                      Óskar Thór Axelsson
# cast            Jóhannes Haukur Jóhannesson, Ágústa Eva Erlend...
# country                                                   Iceland
# date_added                                         March 27, 2018
# release_year                                                 2017
# duration                                                      106
# description     Young urbanites renovating a rundown house, an...
# genre                                               Horror Movies
# Name: 41, dtype: object)
# (42, show_id                                                       s43
# type                                                        Movie
# title                                 Çok Filim Hareketler Bunlar
# director                                             Ozan Açıktan
# cast            Ayça Erturan, Aydan Taş, Ayşegül Akdemir, Burc...
# country                                                    Turkey
# date_added                                         March 10, 2017
# release_year                                                 2010
# duration                                                       99
# description     Vignettes of the summer holidays follow vacati...
# genre                                                    Comedies
# Name: 42, dtype: object)
# (43, show_id                                                       s44
# type                                                        Movie
# title                                                     Òlòtūré
# director                                            Kenneth Gyang
# cast            Beverly Osu, Sharon Ooja, Omowunmi Dada, Pearl...
# country                                                   Nigeria
# date_added                                        October 2, 2020
# release_year                                                 2020
# duration                                                      107
# description     In Lagos, a journalist goes undercover as a pr...
# genre                                                      Dramas
# Name: 43, dtype: object)
# (44, show_id                                                       s45
# type                                                        Movie
# title                                                    Æon Flux
# director                                             Karyn Kusama
# cast            Charlize Theron, Marton Csokas, Jonny Lee Mill...
# country                                             United States
# date_added                                       February 1, 2018
# release_year                                                 2005
# duration                                                       93
# description     Aiming to hasten an uprising, the leader of an...
# genre                                                      Action
# Name: 44, dtype: object)
# (45, show_id                                                       s46
# type                                                      TV Show
# title                                                       Şubat
# director                                                      NaN
# cast            Alican Yücesoy, Melisa Sözen, Musa Uzunlar, Se...
# country                                                    Turkey
# date_added                                       January 17, 2017
# release_year                                                 2013
# duration                                                        1
# description     An orphan subjected to tests that gave him sup...
# genre                                                    Crime TV
# Name: 45, dtype: object)
# (46, show_id                                                       s47
# type                                                        Movie
# title                                            1 Chance 2 Dance
# director                                               Adam Deyoe
# cast            Lexi Giovagnoli, Justin Ray, Rae Latt, Poonam ...
# country                                             United States
# date_added                                           July 1, 2017
# release_year                                                 2014
# duration                                                       89
# description     When an aspiring dancer is uprooted during her...
# genre                                                      Dramas
# Name: 46, dtype: object)
# (47, show_id                                                       s48
# type                                                        Movie
# title                                               1 Mile to You
# director                                              Leif Tilden
# cast            Billy Crudup, Graham Rogers, Liana Liberato, S...
# country                                             United States
# date_added                                           July 7, 2017
# release_year                                                 2017
# duration                                                      105
# description     After escaping the bus accident that killed hi...
# genre                                                      Dramas
# Name: 47, dtype: object)
# (48, show_id                                                       s49
# type                                                        Movie
# title                                         10 Days in Sun City
# director                                                Adze Ugah
# cast            Ayo Makun, Adesua Etomi, Richard Mofe-Damijo, ...
# country                                              South Africa
# date_added                                       October 18, 2019
# release_year                                                 2017
# duration                                                       87
# description     After his girlfriend wins the Miss Nigeria pag...
# genre                                                    Comedies
# Name: 48, dtype: object)
# (49, show_id                                                       s50
# type                                                        Movie
# title                                              10 jours en or
# director                                        Nicolas Brossette
# cast            Franck Dubosc, Claude Rich, Marie Kremer, Math...
# country                                                    France
# date_added                                           July 1, 2017
# release_year                                                 2012
# duration                                                       97
# description     When a carefree bachelor is unexpectedly left ...
# genre                                                    Comedies
# Name: 49, dtype: object)
# (50, show_id                                                       s51
# type                                                        Movie
# title                                                 10,000 B.C.
# director                                          Roland Emmerich
# cast            Steven Strait, Camilla Belle, Cliff Curtis, Jo...
# country                                             United States
# date_added                                           June 1, 2019
# release_year                                                 2008
# duration                                                      109
# description     Fierce mammoth hunter D'Leh sets out on an imp...
# genre                                                      Action
# Name: 50, dtype: object)
# (51, show_id                                                       s52
# type                                                      TV Show
# title                                          100 Days My Prince
# director                                                      NaN
# cast            Doh Kyung-soo, Nam Ji-hyun, Cho Seong-ha, Cho ...
# country                                               South Korea
# date_added                                       December 7, 2020
# release_year                                                 2018
# duration                                                        1
# description     Upon losing his memory, a crown prince encount...
# genre                                            International TV
# Name: 51, dtype: object)
# (52, show_id                                                       s53
# type                                                        Movie
# title                                        100 Days Of Solitude
# director                                                      NaN
# cast                                                          NaN
# country                                                     Spain
# date_added                                           July 6, 2018
# release_year                                                 2018
# duration                                                       93
# description     Spanish photographer José Díaz spends 100 days...
# genre                                               Documentaries
# Name: 52, dtype: object)
# (53, show_id                                                       s54
# type                                                      TV Show
# title                                                  100 Humans
# director                                                      NaN
# cast                       Zainab Johnson, Sammy Obeid, Alie Ward
# country                                             United States
# date_added                                         March 13, 2020
# release_year                                                 2020
# duration                                                        1
# description     One hundred hardy souls from diverse backgroun...
# genre                                                  Docuseries
# Name: 53, dtype: object)
# (54, show_id                                                       s55
# type                                                        Movie
# title                                                  100 Meters
# director                                           Marcel Barrena
# cast            Dani Rovira, Karra Elejalde, Alexandra Jiménez...
# country                                                  Portugal
# date_added                                         March 10, 2017
# release_year                                                 2016
# duration                                                      109
# description     A man who is diagnosed with multiple sclerosis...
# genre                                                      Dramas
# Name: 54, dtype: object)
# (55, show_id                                                       s56
# type                                                        Movie
# title                         100 Things to do Before High School
# director                                                      NaN
# cast            Isabela Moner, Jaheem Toombs, Owen Joyner, Jac...
# country                                             United States
# date_added                                       November 2, 2019
# release_year                                                 2014
# duration                                                       44
# description     Led by seventh-grader C.J., three students who...
# genre                                               Uncategorized
# Name: 55, dtype: object)
# (56, show_id                                                       s57
# type                                                        Movie
# title                    100 Years: One Woman's Fight for Justice
# director                                            Melinda Janko
# cast                                                          NaN
# country                                             United States
# date_added                                         March 20, 2018
# release_year                                                 2016
# duration                                                       75
# description     This documentary chronicles Elouise Cobell's l...
# genre                                               Documentaries
# Name: 56, dtype: object)
# (57, show_id                                                       s58
# type                                                        Movie
# title                                                  100% Halal
# director                                            Jastis Arimba
# cast            Anisa Rahma, Ariyo Wahab, Anandito Dwis, Fitri...
# country                                                 Indonesia
# date_added                                        January 7, 2021
# release_year                                                 2020
# duration                                                      101
# description     After high school, a young woman marries the m...
# genre                                                      Dramas
# Name: 57, dtype: object)
# (58, show_id                                                       s59
# type                                                      TV Show
# title                                                 100% Hotter
# director                                                      NaN
# cast            Daniel Palmer, Melissa Sophia, Karen Williams,...
# country                                            United Kingdom
# date_added                                       November 1, 2019
# release_year                                                 2017
# duration                                                        1
# description     A stylist, a hair designer and a makeup artist...
# genre                                                  British TV
# Name: 58, dtype: object)
# (59, show_id                                                       s60
# type                                                        Movie
# title                                             1000 Rupee Note
# director                                           Shrihari Sathe
# cast            Usha Naik, Sandeep Pathak, Shrikant Yadav, Gan...
# country                                                     India
# date_added                                       December 1, 2016
# release_year                                                 2014
# duration                                                       89
# description     After randomly receiving a handsome political ...
# genre                                                      Dramas
# Name: 59, dtype: object)
# (60, show_id                                                       s61
# type                                                        Movie
# title                                                12 ROUND GUN
# director                                                Sam Upton
# cast            Sam Upton, Jared Abrahamson, Mark Boone Junior...
# country                                             United States
# date_added                                         March 14, 2019
# release_year                                                 2017
# duration                                                       90
# description     Dealing with personal demons and the death of ...
# genre                                                      Dramas
# Name: 60, dtype: object)
# (61, show_id                                                       s62
# type                                                      TV Show
# title                                            12 Years Promise
# director                                                      NaN
# cast            So-yeon Lee, Namkoong Min, Tae-im Lee, So-hui ...
# country                                               South Korea
# date_added                                           May 22, 2017
# release_year                                                 2014
# duration                                                        1
# description     A pregnant teen is forced by her family to lea...
# genre                                            International TV
# Name: 61, dtype: object)
# (62, show_id                                                       s63
# type                                                        Movie
# title                                                  13 Cameras
# director                                           Victor Zarcoff
# cast            PJ McCabe, Brianne Moncrief, Sarah Baldwin, Ji...
# country                                             United States
# date_added                                        August 13, 2016
# release_year                                                 2015
# duration                                                       90
# description     Young parents-to-be Claire and Ryan move into ...
# genre                                               Horror Movies
# Name: 62, dtype: object)
# (63, show_id                                                       s64
# type                                                      TV Show
# title                                              13 Reasons Why
# director                                                      NaN
# cast            Dylan Minnette, Katherine Langford, Kate Walsh...
# ...
# country                                                    Taiwan
# date_added                                      December 21, 2018
# release_year                                                 2017
# duration                                                        1
# description     After crossing paths at a crime scene, a renow...
# genre                                            International TV
# Name: 3649, dtype: object)
# (3650, show_id                                                     s3651
# type                                                        Movie
# title                                                Lion's Heart
# director                                           Karim El Sobky
# cast            Mohamed Ramadan, Hassan Hosny, Horeya Farghaly...
# country                                                     Egypt
# date_added                                            May 9, 2019
# release_year                                                 2013
# duration                                                      111
# description     Kidnapped as a child and raised in the circus,...
# genre                                                      Action
# Name: 3650, dtype: object)
# (3651, show_id                                                     s3652
# type                                                        Movie
# title                                                   Lionheart
# director                                          Genevieve Nnaji
# cast            Genevieve Nnaji, Nkem Owoh, Pete Edochie, Onye...
# country                                                   Nigeria
# date_added                                        January 4, 2019
# release_year                                                 2018
# duration                                                       95
# description     When her father falls ill, Adaeze steps up to ...
# genre                                                    Comedies
# Name: 3651, dtype: object)
# (3652, show_id                                                     s3653
# type                                                        Movie
# title                           Liss Pereira: Reteniendo líquidos
# director                                          Fernando Ayllón
# cast                                                 Liss Pereira
# country                                                    Brazil
# date_added                                         April 10, 2019
# release_year                                                 2019
# duration                                                       59
# description     A pregnant Liss Pereira shares hilariously unc...
# genre                                                    Stand-Up
# Name: 3652, dtype: object)
# (3653, show_id                                                     s3654
# type                                                        Movie
# title                                                      Listen
# director                                       Philippe Aractingi
# cast            Hadi Bou Ayash, Ruba Zarour, Yara Bou Nassar, ...
# country                                                   Lebanon
# date_added                                       October 19, 2020
# release_year                                                 2017
# duration                                                      103
# description     A sound engineer falls for a model but after a...
# genre                                                      Dramas
# Name: 3653, dtype: object)
# (3654, show_id                                                     s3655
# type                                                        Movie
# title                        Listen Up! The Lives of Quincy Jones
# director                                          Ellen Weissbrod
# cast            Quincy Jones, Miles Davis, Ray Charles, Sheila...
# country                                                       NaN
# date_added                                       November 1, 2019
# release_year                                                 1990
# duration                                                      116
# description     Steering clear of convention, this affecting d...
# genre                                               Documentaries
# Name: 3654, dtype: object)
# (3655, show_id                                                     s3656
# type                                                        Movie
# title                                  Little Baby Bum: Go Buster
# director                                                      NaN
# cast                                                          NaN
# country                                                       NaN
# date_added                                        October 1, 2019
# release_year                                                 2019
# duration                                                       58
# description     This compilation for preschoolers features a p...
# genre                                                    Children
# Name: 3655, dtype: object)
# (3656, show_id                                                     s3657
# type                                                      TV Show
# title                      Little Baby Bum: Nursery Rhyme Friends
# director                                                      NaN
# cast                    Chloe Marsden, Aaron Marsden, María Esnoz
# country                                            United Kingdom
# date_added                                       October 18, 2019
# release_year                                                 2019
# duration                                                        2
# description     Twinkle, Mia, Jacus and the rest of the Nurser...
# genre                                                  British TV
# Name: 3656, dtype: object)
# (3657, show_id                                                     s3658
# type                                                        Movie
# title                                                Little Boxes
# director                                                Rob Meyer
# cast            Melanie Lynskey, Nelsan Ellis, Armani Jackson,...
# country                                             United States
# date_added                                           June 1, 2017
# release_year                                                 2016
# duration                                                       89
# description     After moving from New York City to a small tow...
# genre                                                    Comedies
# Name: 3657, dtype: object)
# (3658, show_id                                                     s3659
# type                                                        Movie
# title                                        Little Dragon Maiden
# director                                                 Hua Shan
# cast            Leslie Cheung, Jing-Jing Yung, Chen Kuan-tai, ...
# country                                                 Hong Kong
# date_added                                         August 1, 2018
# release_year                                                 1983
# duration                                                       92
# description     Seeking to improve his combat skills, a young ...
# genre                                                      Action
# Name: 3658, dtype: object)
# (3659, show_id                                                     s3660
# type                                                        Movie
# title                                                 Little Evil
# director                                                Eli Craig
# cast            Adam Scott, Evangeline Lilly, Bridget Everett,...
# country                                             United States
# date_added                                      September 1, 2017
# release_year                                                 2017
# duration                                                       95
# description     In this horror-comedy, a recently married man ...
# genre                                                    Comedies
# Name: 3659, dtype: object)
# (3660, show_id                                                     s3661
# type                                                      TV Show
# title                                                Little Lunch
# director                                                      NaN
# cast            Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# country                                                 Australia
# date_added                                       February 1, 2018
# release_year                                                 2015
# duration                                                        1
# description     Adopting a child's perspective, this show take...
# genre                                                        Kids
# Name: 3660, dtype: object)
# (3661, show_id                                                     s3662
# type                                                        Movie
# title                    Little Lunch: The Halloween Horror Story
# director                                              Tim Bartley
# cast            Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# country                                                 Australia
# date_added                                         March 15, 2018
# release_year                                                 2016
# duration                                                       23
# description     When the class puts on a Halloween play about ...
# genre                                                    Children
# Name: 3661, dtype: object)
# (3662, show_id                                                     s3663
# type                                                        Movie
# title               Little Lunch: The Nightmare Before Graduation
# director                                             Robyn Butler
# cast            Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# country                                                 Australia
# date_added                                         March 15, 2018
# release_year                                                 2016
# duration                                                       25
# description     Mrs. Gonsha's students are excited about the e...
# genre                                                    Children
# Name: 3662, dtype: object)
# (3663, show_id                                                     s3664
# type                                                        Movie
# title                                                  Little Men
# director                                                Ira Sachs
# cast            Greg Kinnear, Jennifer Ehle, Paulina García, A...
# country                                             United States
# date_added                                       January 12, 2017
# release_year                                                 2016
# duration                                                       85
# description     Jake and Tony become friends when Jake's dad i...
# genre                                                      Dramas
# Name: 3663, dtype: object)
# (3664, show_id                                                     s3665
# type                                                        Movie
# title                                            Little Miss Sumo
# director                                                 Matt Kay
# cast                                                   Hiyori Kon
# country                                            United Kingdom
# date_added                                       October 28, 2019
# release_year                                                 2018
# duration                                                       20
# description     In an ancient sport traditionally reserved for...
# genre                                               Documentaries
# Name: 3664, dtype: object)
# (3665, show_id                                                     s3666
# type                                                        Movie
# title                                             Little Monsters
# director                                        Richard Greenberg
# cast            Fred Savage, Howie Mandel, Daniel Stern, Marga...
# country                                             United States
# date_added                                       November 1, 2020
# release_year                                                 1989
# duration                                                      102
# description     Brian knows there are creatures under his bed....
# genre                                                    Children
# Name: 3665, dtype: object)
# (3666, show_id                                                     s3667
# type                                                        Movie
# title                                                Little Nicky
# director                                              Steve Brill
# cast            Adam Sandler, Patricia Arquette, Harvey Keitel...
# country                                             United States
# date_added                                       December 1, 2020
# release_year                                                 2000
# duration                                                       90
# description     The devil sends his sweet son Nicky to Earth t...
# genre                                                    Comedies
# Name: 3666, dtype: object)
# (3667, show_id                                                     s3668
# type                                                      TV Show
# title                                              Little Singham
# director                                                      NaN
# cast            Swapnil Kumari, Jigna Bhardwaj, Sonal Kaushal,...
# country                                                     India
# date_added                                           July 4, 2020
# release_year                                                 2020
# duration                                                        2
# description     A spinoff of Rohit Shetty's action franchise, ...
# genre                                                        Kids
# Name: 3667, dtype: object)
# (3668, show_id                                                     s3669
# type                                                        Movie
# title                         Little Singham aur Kaal ka Mahajaal
# director                                            Prakash Satam
# cast                                                          NaN
# country                                                       NaN
# date_added                                       December 1, 2018
# release_year                                                 2018
# duration                                                       68
# description     When Kaal, the vilest demon on earth, threaten...
# genre                                                    Children
# Name: 3668, dtype: object)
# (3669, show_id                                                     s3670
# type                                                        Movie
# title                      Little Singham Bandarpur Mein Hu Ha Hu
# director                                                      NaN
# cast            Anamaya Verma, Ganesh Divekar, Jigna Bharadhwa...
# country                                                       NaN
# date_added                                          July 11, 2019
# release_year                                                 2019
# duration                                                       67
# description     Little Singham's sidekick monkey, Chikki, is s...
# genre                                                    Children
# Name: 3669, dtype: object)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
netflix_subset = netflix_df.drop(netflix_df[netflix_df['type']=='TV Show'].index)
print(netflix_subset)
# Out:
#      show_id  ...          genre
# 1         s2  ...         Dramas
# 2         s3  ...  Horror Movies
# 3         s4  ...         Action
# 4         s5  ...         Dramas
# 6         s7  ...  Horror Movies
# ...      ...  ...            ...
# 7781   s7782  ...       Children
# 7782   s7783  ...         Dramas
# 7783   s7784  ...         Dramas
# 7784   s7785  ...  Documentaries
# 7786   s7787  ...  Documentaries
#
# [5377 rows x 11 columns]

# %%
netflix_movies = netflix_subset[['title','country','genre','release_year','duration']]
print(netflix_movies)
# Out:
#                                         title  ... duration
# 1                                        7:19  ...       93
# 2                                       23:59  ...       78
# 3                                           9  ...       80
# 4                                          21  ...      123
# 6                                         122  ...       95
# ...                                       ...  ...      ...
# 7781                                     Zoom  ...       88
# 7782                                     Zozo  ...       99
# 7783                                   Zubaan  ...      111
# 7784                        Zulu Man in Japan  ...       44
# 7786  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  ...       90
#
# [5377 rows x 5 columns]

# %%
short_movies = netflix_movies.drop(netflix_movies[netflix_movies['duration']>=60].index)

# %%
colors=[]
for lab,row in netflix_movies.iterrows():
    if(row['genre']=='Children'):
        colors.append('orange')
    elif(row['genre']=='Documentaries'):
        colors.append('black')
    elif(row['genre']=='Stand-Up'):
        colors.append('yellow')
    else:
        colors.append('purple')

import matplotlib.pyplot as plt
fig = plt.figure()
plt.title("Movie Duration by Year of Release")
plt.xlabel("Release year")
plt.ylabel("Duration (min)")
plt.scatter(netflix_movies['release_year'],netflix_movies['duration'],c=colors)

# %%
answer="no"
